# %% [markdown]
# ### part 1

# %%
import re
trans_file = open("IEMOCAP_full_release/Session1/dialog/transcriptions/Ses01F_impro01.txt","r")
emo_file = open("IEMOCAP_full_release/Session1/dialog/EmoEvaluation/Ses01F_impro01.txt","r")
count = -1

lst1 = []
for line in emo_file:
    count += 1
    if count < 2:
        continue
    
    if (count-2)%9 == 0:
        regex1 = r'\d+\.\d+'
        regex2 = r'neu|xxx|fru|ang'
        match1 = re.search(regex1, line)
        match2 = re.search(regex2, line)
        lst1.append((float(match1[0]), match2[0]))
lst1 = sorted(lst1, key = lambda x: x[0])

result = []
count = 0
for line in trans_file:
    sentence = line[41:]
    sentence = sentence.rstrip()
    result.append((sentence, lst1[count][1]))
    count += 1

# %%
import pandas as pd
df1 = pd.DataFrame(result, columns = ['sentence', 'label'])

# %%
df1
# Out:
#                                              sentence label
# 0                                          Excuse me.   neu
# 1                             Do you have your forms?   fru
# 2                                               Yeah.   neu
# 3                                    Let me see them.   fru
# 4                                 Is there a problem?   neu
# 5                   Who told you to get in this line?   fru
# 6                                            You did.   xxx
# 7   You were standing at the beginning and you dir...   xxx
# 8   Okay. But I didn't tell you to get in this lin...   fru
# 9         Well what's the problem?  Let me change it.   neu
# 10                           This form is a Z.X.four.   fru
# 11  You can't--  This is not the line for Z.X.four...   fru
# 12  What?  I'm getting an ID.  This is why I'm her...   fru
# 13  No. I need another set of ID to prove this is ...   fru
# 14  How am I supposed to get an ID without an ID? ...   fru
# ...

# %%
import re
trans_file = open("IEMOCAP_full_release/Session1/dialog/transcriptions/Ses01F_impro02.txt","r")
emo_file = open("IEMOCAP_full_release/Session1/dialog/EmoEvaluation/Ses01F_impro02.txt","r")
count = -1

lst1 = []
for line in emo_file:
    count += 1
    if count < 2:
        continue
    
    if (count-2)%9 == 0:
        regex1 = r'\d+\.\d+'
        regex2 = r'neu|xxx|fru|ang|sad'
        match1 = re.search(regex1, line)
        match2 = re.search(regex2, line)
        lst1.append((float(match1[0]), match2[0]))
lst1 = sorted(lst1, key = lambda x: x[0])

result = []
count = 0
for line in trans_file:
    sentence = line[41:]
    sentence = sentence.rstrip()
    result.append((sentence, lst1[count][1]))
    count += 1

# %%
df2 = pd.DataFrame(result, columns = ['sentence', 'label'])

# %%
df2
# Out:
#                                              sentence label
# 0         Did you get the mail? So you saw my letter?   sad
# 1                                      It's not fair.   xxx
# 2                                      Yeah.  I know.   sad
# 3   I don't understand.  You've already done so mu...   sad
# 4   I don't know.  I put in that. request too. The...   sad
# 5   I guess, you know, everybody has to make sacri...   neu
# 6   I don't know, it's just not fair.  I think you...   xxx
# 7   There's people that have given more though, yo...   sad
# 8   I just don't see how they can make you leave w...   fru
# 9                                             I know.   sad
# 10                      Then why is that fair?  Why--   xxx
# 11  There's babies over there, though, that need m...   neu
# 12  I don't know how you can be okay with this?  I...   sad
# 13  I'm not okay with it, but I don't-- it's not l...   xxx
# 14  I'm just trying to think of another way.  I'm ...   xxx
# ...

# %%
trans_file = open("IEMOCAP_full_release/Session1/dialog/transcriptions/Ses01F_impro03.txt","r")
emo_file = open("IEMOCAP_full_release/Session1/dialog/EmoEvaluation/Ses01F_impro03.txt","r")
count = -1

lst1 = []
for line in emo_file:
    count += 1
    if count < 2:
        continue
    
    if (count-2)%10 == 0:
        regex1 = r'\d+\.\d+'
        regex2 = r'neu|xxx|fru|ang|sad|hap|exc|sur'
        match1 = re.search(regex1, line)
        match2 = re.search(regex2, line)
        lst1.append((float(match1[0]), match2[0]))
lst1 = sorted(lst1, key = lambda x: x[0])

result = []
count = 0
for line in trans_file:
    sentence = line[41:]
    sentence = sentence.rstrip()
    result.append((sentence, lst1[count][1]))
    count += 1

# %%
df3 = pd.DataFrame(result, columns = ['sentence', 'label'])

# %%
df3
# Out:
#                                              sentence label
# 0                          So what's up?  What's new?   neu
# 1                             Well Vegas was awesome.   hap
# 2                                     Yeah.  I heard.   neu
# 3                             And, um, I got married.   hap
# 4                             Shut up.  No- in Vegas?   sur
# 5                        Yeah.  In the old town part.   hap
# 6                                  Who did you marry?   exc
# 7                                   Chuck. [LAUGHTER]   xxx
# 8                             Did you propose to you?   xxx
# 9                     Um- Yes.  It was very romantic.   hap
# 10                       It was at the slot machines.   hap
# 11                   Oh.  The Wheel of Fortune slots?   xxx
# 12  Uhuh, uhuh.  He won big and he-and he realized...   hap
# 13                   He turned to you and was like...   neu
# 14           Hey.  Let's get married and I said okay.   xxx
# ...

# %%
trans_file = open("IEMOCAP_full_release/Session1/dialog/transcriptions/Ses01F_impro04.txt","r")
emo_file = open("IEMOCAP_full_release/Session1/dialog/EmoEvaluation/Ses01F_impro04.txt","r")
count = -1

lst1 = []
for line in emo_file:
    count += 1
    if count < 2:
        continue
    
    if (count-2)%9 == 0:
        regex1 = r'\d+\.\d+'
        regex2 = r'neu|xxx|fru|ang|sad|hap|exc|sur'
        match1 = re.search(regex1, line)
        match2 = re.search(regex2, line)
        lst1.append((float(match1[0]), match2[0]))
lst1 = sorted(lst1, key = lambda x: x[0])

result = []
count = 0
for line in trans_file:
    sentence = line[41:]
    sentence = sentence.rstrip()
    result.append((sentence, lst1[count][1]))
    count += 1

# %%
df4 = pd.DataFrame(result, columns = ['sentence', 'label'])

# %%
df4
# Out:
#                                              sentence label
# 0                   Have you tried, uh, Craig's List?   neu
# 1    Uh, what?  Craig's List?  Oh the internet thing?   neu
# 2                                               Yeah.   neu
# 3   I don't know.  Isn't that-- that's all like es...   neu
# 4                 No.  There's regular jobs on there.   neu
# ..                                                ...   ...
# 66                        What? Oh.  So now you're...   fru
# 67     The bus, I'm riding the bus because I want to.   ang
# 68  you know what?  You don't have to take your an...   fru
# 69  I can not-- you are not here by choice.  Nobod...   ang
# 70                                           Why not?   xxx
#
# [71 rows x 2 columns]

# %%
trans_file = open("IEMOCAP_full_release/Session1/dialog/transcriptions/Ses01F_impro05.txt","r")
emo_file = open("IEMOCAP_full_release/Session1/dialog/EmoEvaluation/Ses01F_impro05.txt","r")
count = -1

lst1 = []
for line in emo_file:
    count += 1
    if count < 2:
        continue
    
    if (count-2)%9 == 0:
        regex1 = r'\d+\.\d+'
        regex2 = r'neu|xxx|fru|ang|sad|hap|exc|sur'
        match1 = re.search(regex1, line)
        match2 = re.search(regex2, line)
        lst1.append((float(match1[0]), match2[0]))
lst1 = sorted(lst1, key = lambda x: x[0])

result = []
count = 0
for line in trans_file:
    sentence = line[41:]
    sentence = sentence.rstrip()
    result.append((sentence, lst1[count][1]))
    count += 1

df5 = pd.DataFrame(result, columns = ['sentence', 'label'])

# %%
df5
# Out:
#                                              sentence label
# 0                                                 Hi.   neu
# 1                            Hi.  Thanks for waiting.   fru
# 2   Yeah. This is the fourth line that I have been...   hap
# 3                                     Can I help you?   fru
# 4                                             Uh huh.   hap
# ..                                                ...   ...
# 62  Why?  Have I done something wrong?  Have I giv...   sur
# 63  I don't think you have done everything you cou...   ang
# 64  If you want, you can write a letter.  I can gi...   neu
# 65         A letter? I'll make a personal phone call.   ang
# 66  Or you can make a phone call.  But I think a l...   neu
#
# [67 rows x 2 columns]

# %%
trans_file = open("IEMOCAP_full_release/Session1/dialog/transcriptions/Ses01F_impro06.txt","r")
emo_file = open("IEMOCAP_full_release/Session1/dialog/EmoEvaluation/Ses01F_impro06.txt","r")
count = -1

lst1 = []
for line in emo_file:
    count += 1
    if count < 2:
        continue
    
    if (count-2)%9 == 0:
        regex1 = r'\d+\.\d+'
        regex2 = r'neu|xxx|fru|ang|sad|hap|exc|sur'
        match1 = re.search(regex1, line)
        match2 = re.search(regex2, line)
        lst1.append((float(match1[0]), match2[0]))
lst1 = sorted(lst1, key = lambda x: x[0])

result = []
count = 0
for line in trans_file:
    sentence = line[41:]
    sentence = sentence.rstrip()
    result.append((sentence, lst1[count][1]))
    count += 1

df6 = pd.DataFrame(result, columns = ['sentence', 'label'])

# %%
df6
# Out:
#                                              sentence label
# 0                                     I'm sorry, Joy.   sad
# 1                                          It's okay.   xxx
# 2   Is there anything I can get you?  Do you want ...   neu
# 3                                         No, no, no.   xxx
# 4                                ...pick up anything?   neu
# 5                                                 No.   sad
# 6   You know you are welcome to stay at my house i...   sad
# 7                                       That's sweet.   neu
# 8                                          Thank you.   neu
# 9      I went to see her headstone a week or two ago.   sad
# 10  I used to go to cemeteries a lot before she di...   sad
# 11                                               Hmm.   neu
# 12  So I was like wandering around before.  It tak...   sad
# 13  So I was looking at this other one and there w...   sad
# 14  this woman came up and, you know, it was hers....   neu
# ...

# %%
trans_file = open("IEMOCAP_full_release/Session1/dialog/transcriptions/Ses01F_impro07.txt","r")
emo_file = open("IEMOCAP_full_release/Session1/dialog/EmoEvaluation/Ses01F_impro07.txt","r")
count = -1

lst1 = []
for line in emo_file:
    count += 1
    if count < 2:
        continue
    
    if (count-2)%9 == 0:
        regex1 = r'\d+\.\d+'
        regex2 = r'neu|xxx|fru|ang|sad|hap|exc|sur'
        match1 = re.search(regex1, line)
        match2 = re.search(regex2, line)
        lst1.append((float(match1[0]), match2[0]))
lst1 = sorted(lst1, key = lambda x: x[0])

result = []
count = 0
for line in trans_file:
    sentence = line[41:]
    sentence = sentence.rstrip()
    result.append((sentence, lst1[count][1]))
    count += 1

df7 = pd.DataFrame(result, columns = ['sentence', 'label'])

# %%
df7
# Out:
#                                              sentence label
# 0                             Did you get the letter?   exc
# 1   Yes.  There's a big envelope it says, you're i...   exc
# 2                           Yeah. That is so awesome.   exc
# 3     Oh my God. What are you going to do? [LAUGHTER]   xxx
# 4   So I have to move back to the ghetto but...I k...   exc
# 5   Oh-Yeah, I bet you're really excited. Oh.  Tha...   exc
# 6   I'm really excited.  Yeah. I don't know how I'...   exc
# 7   Oh.  Good, good.  That's awesome. Are you goin...   exc
# 8                 Oh- I know, I know, I know, I know.   exc
# 9   I don't know.  I spend so much time commuting ...   exc
# 10  This is so- I am so happy that you're going to...   exc
# 11                   I know. We should throw a party.   exc
# 12  At Arapaho we could afford that. [GARBAGE]. Ye...   xxx
# 13                     A rapper party ho. Yeah. Okay.   exc
# 14  I am just- Yeah.  I'm sticking around, I'm jus...   exc
# ...

# %%
df = pd.concat([df1, df2, df3, df4, df5, df6, df7])

# %%
df
# Out:
#                                              sentence label
# 0                                          Excuse me.   neu
# 1                             Do you have your forms?   fru
# 2                                               Yeah.   neu
# 3                                    Let me see them.   fru
# 4                                 Is there a problem?   neu
# ..                                                ...   ...
# 32                                Yay...School's fun.   exc
# 33  Of course, right.  That's where the real money...   neu
# 34                         Yeah.  Totally. [LAUGHTER]   xxx
# 35  That's how you get the big bucks.  Are you mes...   hap
# 36  I know. I made such a mess of it, the entire t...   exc
#
# [342 rows x 2 columns]

# %%
df.to_csv("session1_1.csv")

# %% [markdown]
# ### part 2

# %%
trans_file = open("IEMOCAP_full_release/Session1/dialog/transcriptions/Ses01F_script01_1.txt","r")
emo_file = open("IEMOCAP_full_release/Session1/dialog/EmoEvaluation/Ses01F_script01_1.txt","r")
count = -1

lst1 = []
for line in emo_file:
    count += 1
    if count < 2:
        continue
    
    if (count-2)%8 == 0:
        regex1 = r'\d+\.\d+'
        regex2 = r'neu|xxx|fru|ang|sad|hap|exc|sur'
        match1 = re.search(regex1, line)
        match2 = re.search(regex2, line)
        lst1.append((float(match1[0]), match2[0]))
lst1 = sorted(lst1, key = lambda x: x[0])

result = []
count = 0
for line in trans_file:
    sentence = line[43:]
    sentence = sentence.rstrip()
    result.append((sentence, lst1[count][1]))
    count += 1

df1 = pd.DataFrame(result, columns = ['sentence', 'label'])

# %%
df1
# Out:
#                                              sentence label
# 0                             What's he going to say?   fru
# 1         Maybe we should tell him before he sees it.   xxx
# 2                                          He saw it.   neu
# 3    How could he see it?  I was the first one up;...   sur
# 4                      He was out here when it broke.   neu
# ..                                                ...   ...
# 84                        Just don't think like that.   ang
# 85                      Well I am thinking like that.   fru
# 86                      I don't understand you, do I?   fru
# 87           No.  You don't.  I'm a pretty tough guy.   fru
# 88                                    I can see that.   fru
#
# [89 rows x 2 columns]

# %%
trans_file = open("IEMOCAP_full_release/Session1/dialog/transcriptions/Ses01F_script01_2.txt","r")
emo_file = open("IEMOCAP_full_release/Session1/dialog/EmoEvaluation/Ses01F_script01_2.txt","r")
count = -1

lst1 = []
for line in emo_file:
    count += 1
    if count < 2:
        continue
    
    if (count-2)%7 == 0:
        regex1 = r'\d+\.\d+'
        regex2 = r'neu|xxx|fru|ang|sad|hap|exc|sur'
        match1 = re.search(regex1, line)
        match2 = re.search(regex2, line)
        lst1.append((float(match1[0]), match2[0]))
lst1 = sorted(lst1, key = lambda x: x[0])

result = []
count = 0
for line in trans_file:
    sentence = line[43:]
    sentence = sentence.rstrip()
    result.append((sentence, lst1[count][1]))
    count += 1

df2 = pd.DataFrame(result, columns = ['sentence', 'label'])

# %%
df2
# Out:
#                                              sentence label
# 0                         Why did he invite her here?   xxx
# 1                           Why does that bother you?   xxx
# 2    She's been in New York three and an half year...   xxx
# 3       Well maybe...maybe he just wanted to see her.   neu
# 4       Nobody comes seven hundred miles just to see.   xxx
# 5    What do you mean?  You know he lived next doo...   xxx
# 6    [BREATHING] You don't look at me like that.  ...   fru
# 7                        He's not going to marry her.   ang
# 8        How do you know he's even thinking about it?   neu
# 9                             It's got that about it.   ang
# 10                                      Oh.  So what.   xxx
# 11                        What is going on here, Joe?   ang
# 12                                        Now listen.   fru
# 13         She is not his girl.  She knows she's not.   ang
# 14                           You can't read her mind.   fru
# ...

# %%
trans_file = open("IEMOCAP_full_release/Session1/dialog/transcriptions/Ses01F_script01_3.txt","r")
emo_file = open("IEMOCAP_full_release/Session1/dialog/EmoEvaluation/Ses01F_script01_3.txt","r")
count = -1

lst1 = []
for line in emo_file:
    count += 1
    if count < 2:
        continue
    
    if (count-2)%8 == 0:
        regex1 = r'\d+\.\d+'
        regex2 = r'neu|xxx|fru|ang|sad|hap|exc|sur'
        match1 = re.search(regex1, line)
        match2 = re.search(regex2, line)
        lst1.append((float(match1[0]), match2[0]))
lst1 = sorted(lst1, key = lambda x: x[0])

result = []
count = 0
for line in trans_file:
    sentence = line[43:]
    sentence = sentence.rstrip()
    result.append((sentence, lst1[count][1]))
    count += 1

df3 = pd.DataFrame(result, columns = ['sentence', 'label'])

# %%
df3
# Out:
#                                              sentence label
# 0    You're the only one who still loves his parents.   neu
# 1    I know.  It kind of went out of style, didn't...   neu
# 2                 It's not so bad; it's a good thing.   neu
# 3    [BREATHING] You know, it's lovely here.  The ...   neu
# 4                          You're not sorry you came.   neu
# ..                                                ...   ...
# 70                     I just want you to know Annie.   neu
# 71   Because you mustn't feel that way.  Everythin...   xxx
# 72   Even me.  And your money?  Chris, there's not...   xxx
# 73   Annie, Annie.  I am going to make a fortune f...   xxx
# 74                    What would I do with a fortune?   hap
#
# [75 rows x 2 columns]

# %%
trans_file = open("IEMOCAP_full_release/Session1/dialog/transcriptions/Ses01F_script02_1.txt","r")
emo_file = open("IEMOCAP_full_release/Session1/dialog/EmoEvaluation/Ses01F_script02_1.txt","r")
count = -1

lst1 = []
for line in emo_file:
    count += 1
    if count < 2:
        continue
    
    if (count-2)%7 == 0:
        regex1 = r'\d+\.\d+'
        regex2 = r'neu|xxx|fru|ang|sad|hap|exc|sur'
        match1 = re.search(regex1, line)
        match2 = re.search(regex2, line)
        lst1.append((float(match1[0]), match2[0]))
lst1 = sorted(lst1, key = lambda x: x[0])

result = []
count = 0
for line in trans_file:
    sentence = line[43:]
    sentence = sentence.rstrip()
    result.append((sentence, lst1[count][1]))
    count += 1

df4 = pd.DataFrame(result, columns = ['sentence', 'label'])

# %%
df4
# Out:
#                                              sentence label
# 0    What time is it?  I think it's supposed to ru...   xxx
# 1    Actually I want to get a little further up th...   xxx
# 2                                               Fine.   neu
# 3                           Okay.  Is that, is that--   exc
# 4    No.  That's just foam.  I don't know.  I can'...   xxx
# ..                                                ...   ...
# 66   Oh look.  I'm giving myself goose bumps, my h...   xxx
# 67                                   That's the wind.   neu
# 68                              So what do you think?   hap
# 69                                        About what?   neu
# 70   About all of that, about all I was talking ab...   hap
#
# [71 rows x 2 columns]

# %%
trans_file = open("IEMOCAP_full_release/Session1/dialog/transcriptions/Ses01F_script02_2.txt","r")
emo_file = open("IEMOCAP_full_release/Session1/dialog/EmoEvaluation/Ses01F_script02_2.txt","r")
count = -1

lst1 = []
for line in emo_file:
    count += 1
    if count < 2:
        continue
    
    if (count-2)%7 == 0:
        regex1 = r'\d+\.\d+'
        regex2 = r'neu|xxx|fru|ang|sad|hap|exc|sur|oth'
        match1 = re.search(regex1, line)
        match2 = re.search(regex2, line)
        lst1.append((float(match1[0]), match2[0]))
lst1 = sorted(lst1, key = lambda x: x[0])

result = []
count = 0
for line in trans_file:
    sentence = line[43:]
    sentence = sentence.rstrip()
    result.append((sentence, lst1[count][1]))
    count += 1

df5 = pd.DataFrame(result, columns = ['sentence', 'label'])

# %%
df5
# Out:
#                                              sentence label
# 0    Look at this, all of the hairs are standing u...   exc
# 1                                    That's the wind.   neu
# 2                        Well, so, what do you think?   exc
# 3                                         About what?   neu
# 4                            About what I was saying.   neu
# ..                                                ...   ...
# 93   I'm beginning to think this might be the righ...   hap
# 94                                  Augie, I'm sorry.   sad
# 95    Shh.  If we're very quiet, the fish might come.   neu
# 96                                            Or not.   neu
# 97                                            Or not.   hap
#
# [98 rows x 2 columns]

# %%
trans_file = open("IEMOCAP_full_release/Session1/dialog/transcriptions/Ses01F_script03_1.txt","r")
emo_file = open("IEMOCAP_full_release/Session1/dialog/EmoEvaluation/Ses01F_script03_1.txt","r")
count = -1

lst1 = []
for line in emo_file:
    count += 1
    if count < 2:
        continue
    
    if (count-2)%7 == 0:
        regex1 = r'\d+\.\d+'
        regex2 = r'neu|xxx|fru|ang|sad|hap|exc|sur|oth|fea|dis'
        match1 = re.search(regex1, line)
        match2 = re.search(regex2, line)
        lst1.append((float(match1[0]), match2[0]))
lst1 = sorted(lst1, key = lambda x: x[0])

result = []
count = 0
for line in trans_file:
    sentence = line[43:]
    sentence = sentence.rstrip()
    result.append((sentence, lst1[count][1]))
    count += 1

df6 = pd.DataFrame(result, columns = ['sentence', 'label'])

# %%
df6
# Out:
#                                              sentence label
# 0                                           Good God.   fea
# 1                                         Is it them?   fea
# 2                                           I wonder.   fea
# 3    Freda is the only one who knows we are here. ...   fea
# 4                               It must be them then.   fea
# ..                                                ...   ...
# 66   [LAUGHTER] I'll never forget his face. [LAUGH...   hap
# 67         [LAUGHTER] We were very much younger then.   hap
# 68                  [LAUGHTER] And very much sillier.   hap
# 69   However I believe the real cause of that row ...   xxx
# 70           Oh.  You knew there was nothing in that.   xxx
#
# [71 rows x 2 columns]

# %%
trans_file = open("IEMOCAP_full_release/Session1/dialog/transcriptions/Ses01F_script03_2.txt","r")
emo_file = open("IEMOCAP_full_release/Session1/dialog/EmoEvaluation/Ses01F_script03_2.txt","r")
count = -1

lst1 = []
for line in emo_file:
    count += 1
    if count < 2:
        continue
    
    if (count-2)%7 == 0:
        regex1 = r'\d+\.\d+'
        regex2 = r'neu|xxx|fru|ang|sad|hap|exc|sur|oth|fea|dis'
        match1 = re.search(regex1, line)
        match2 = re.search(regex2, line)
        lst1.append((float(match1[0]), match2[0]))
lst1 = sorted(lst1, key = lambda x: x[0])

result = []
count = 0
for line in trans_file:
    sentence = line[43:]
    sentence = sentence.rstrip()
    result.append((sentence, lst1[count][1]))
    count += 1

df7 = pd.DataFrame(result, columns = ['sentence', 'label'])

# %%
df7
# Out:
#                                              sentence label
# 0                     We were very much younger then.   xxx
# 1                              And very much sillier.   hap
# 2    However I believe the real cause of that row ...   neu
# 3            Oh.  You knew there was nothing in that.   hap
# 4    I knew nothing of the sort.  You took present...   neu
# ..                                                ...   ...
# 77                        You're not going like this.   ang
# 78                                     Oh.  Yes I am.   ang
# 79                                        You're not.   ang
# 80   Yes I am.   Stop it. Stop it.  Let go of me. ...   ang
# 81   Shut up. Shut up. God, I wouldn't marry you a...   ang
#
# [82 rows x 2 columns]

# %%
df = pd.concat([df1, df2, df3, df4, df5, df6, df7])

# %%
df
# Out:
#                                              sentence label
# 0                             What's he going to say?   fru
# 1         Maybe we should tell him before he sees it.   xxx
# 2                                          He saw it.   neu
# 3    How could he see it?  I was the first one up;...   sur
# 4                      He was out here when it broke.   neu
# ..                                                ...   ...
# 77                        You're not going like this.   ang
# 78                                     Oh.  Yes I am.   ang
# 79                                        You're not.   ang
# 80   Yes I am.   Stop it. Stop it.  Let go of me. ...   ang
# 81   Shut up. Shut up. God, I wouldn't marry you a...   ang
#
# [519 rows x 2 columns]

# %%
df.to_csv("session1_2.csv")

# %% [markdown]
# ### part 3

# %%
trans_file = open("IEMOCAP_full_release/Session1/dialog/transcriptions/Ses01M_impro01.txt","r")
emo_file = open("IEMOCAP_full_release/Session1/dialog/EmoEvaluation/Ses01M_impro01.txt","r")
count = -1

lst1 = []
for line in emo_file:
    count += 1
    if count < 2:
        continue
    
    if (count-2)%9 == 0:
        regex1 = r'\d+\.\d+'
        regex2 = r'neu|xxx|fru|ang|sad|hap|exc|sur|oth|fea|dis'
        match1 = re.search(regex1, line)
        match2 = re.search(regex2, line)
        lst1.append((float(match1[0]), match2[0]))
lst1 = sorted(lst1, key = lambda x: x[0])

result = []
count = 0
for line in trans_file:
    sentence = line[43:]
    sentence = sentence.rstrip()
    result.append((sentence, lst1[count][1]))
    count += 1

df1 = pd.DataFrame(result, columns = ['sentence', 'label'])

# %%
df1
# Out:
#                                              sentence label
# 0                                                 xt.   ang
# 1                       s, me. Okay, okay here we go.   fru
# 2                                     window is open.   ang
# 3               ay, so filled out all these forms  --   fru
# 4       is is... Your last- Your first name is Jones?   fru
# ..                                                ...   ...
# 60             y, because I'm sick of talking to you.   ang
# 61  ause you're obviously not talking to me, you'r...   xxx
# 62                  , dear. Oh, boo-foo-woo, foo-foo.   fru
# 63  , no honey. And you're going to miss the Chris...   xxx
# 64                                       t back down.   xxx
#
# [65 rows x 2 columns]

# %%
trans_file = open("IEMOCAP_full_release/Session1/dialog/transcriptions/Ses01M_impro02.txt","r")
emo_file = open("IEMOCAP_full_release/Session1/dialog/EmoEvaluation/Ses01M_impro02.txt","r")
count = -1

lst1 = []
for line in emo_file:
    count += 1
    if count < 2:
        continue
    
    if (count-2)%9 == 0:
        regex1 = r'\d+\.\d+'
        regex2 = r'neu|xxx|fru|ang|sad|hap|exc|sur|oth|fea|dis'
        match1 = re.search(regex1, line)
        match2 = re.search(regex2, line)
        lst1.append((float(match1[0]), match2[0]))
lst1 = sorted(lst1, key = lambda x: x[0])

result = []
count = 0
for line in trans_file:
    sentence = line[43:]
    sentence = sentence.rstrip()
    result.append((sentence, lst1[count][1]))
    count += 1

df2 = pd.DataFrame(result, columns = ['sentence', 'label'])

# %%
df2
# Out:
#                                              sentence label
# 0                                y, Joy come in here.   neu
# 1                                     at's happening?   neu
# 2                                    have to go back.   sad
# 3                just got a letter I have to go back.   sad
# 4                                                 en?   xxx
# 5                         rst thing tomorrow morning.   sad
# 6                                   e you kidding me?   sur
# 7                                                w...   fru
# 8                 don't understand, I don't underst--   xxx
# 9                                 w can they do that?   fru
# 10                                      ey can do it.   xxx
# 11       ey said you're home for at least four years.   fru
# 12                              guess they can do it,   fru
# 13  e National Guard is I guess really spread thin...   sad
# 14                                          REATHING]   fru
# ...

# %%
trans_file = open("IEMOCAP_full_release/Session1/dialog/transcriptions/Ses01M_impro03.txt","r")
emo_file = open("IEMOCAP_full_release/Session1/dialog/EmoEvaluation/Ses01M_impro03.txt","r")
count = -1

lst1 = []
for line in emo_file:
    count += 1
    if count < 2:
        continue
    
    if (count-2)%9 == 0:
        regex1 = r'\d+\.\d+'
        regex2 = r'neu|xxx|fru|ang|sad|hap|exc|sur|oth|fea|dis'
        match1 = re.search(regex1, line)
        match2 = re.search(regex2, line)
        lst1.append((float(match1[0]), match2[0]))
lst1 = sorted(lst1, key = lambda x: x[0])

result = []
count = 0
for line in trans_file:
    sentence = line[43:]
    sentence = sentence.rstrip()
    result.append((sentence, lst1[count][1]))
    count += 1

df3 = pd.DataFrame(result, columns = ['sentence', 'label'])

# %%
df3
# Out:
#                                              sentence label
# 0               e craziest thing just happened to me.   exc
# 1                                                 at?   xxx
# 2   is girl; she just offered me fifty thousand do...   exc
# 3                                           REATHING]   sur
# 4                                                 ah.   xxx
# 5                                                  y?   exc
# 6   ll, she's not a citizen so she wants to get a ...   neu
# 7                                     she on the run?   exc
# 8   , no, no, no, no, no she just... she's not a c...   exc
# 9                      , she just needs to marry you.   exc
# 10  at's incredible. That's awesome. Where's she f...   exc
# 11  at's like twenty five thousand dollar a year f...   exc
# 12  e's actually from England, I think.  Well she-...   neu
# 13                              at's so cool. Uh huh.   exc
# 14     AUGHTER] Why did she pick you? Where were you?   exc
# ...

# %%
trans_file = open("IEMOCAP_full_release/Session1/dialog/transcriptions/Ses01M_impro04.txt","r")
emo_file = open("IEMOCAP_full_release/Session1/dialog/EmoEvaluation/Ses01M_impro04.txt","r")
count = -1

lst1 = []
for line in emo_file:
    count += 1
    if count < 2:
        continue
    
    if (count-2)%9 == 0:
        regex1 = r'\d+\.\d+'
        regex2 = r'neu|xxx|fru|ang|sad|hap|exc|sur|oth|fea|dis'
        match1 = re.search(regex1, line)
        match2 = re.search(regex2, line)
        lst1.append((float(match1[0]), match2[0]))
lst1 = sorted(lst1, key = lambda x: x[0])

result = []
count = 0
for line in trans_file:
    sentence = line[43:]
    sentence = sentence.rstrip()
    result.append((sentence, lst1[count][1]))
    count += 1

df4 = pd.DataFrame(result, columns = ['sentence', 'label'])

# %%
df4
# Out:
#                                              sentence label
# 0                                u seem kind of down.   neu
# 1                                         m just mad.   xxx
# 2                                             w come?   xxx
# 3   's--I've been trying to find this job I can't ...   fru
# 4                                        's not fair.   fru
# 5                                     at do you mean?   neu
# 6   mean I've been looking for a job for like thre...   fru
# 7             ere's a lot of people looking for jobs.   neu
# 8   guess.  But three years?  I mean, I like--I we...   fru
# 9           don't know, I mean, I just don't think...   neu
# 10  mean I've been sending out my resumes and doin...   fru
# 11  d you ever think it might be your attitude tha...   neu
# 12      at's my--like what do you mean "my attitude"?   xxx
# 13  don't know just sometimes you get kind of... N...   neu
# 14                        I have an attitude problem?   xxx
# ...

# %%
trans_file = open("IEMOCAP_full_release/Session1/dialog/transcriptions/Ses01M_impro05.txt","r")
emo_file = open("IEMOCAP_full_release/Session1/dialog/EmoEvaluation/Ses01M_impro05.txt","r")
count = -1

lst1 = []
for line in emo_file:
    count += 1
    if count < 2:
        continue
    
    if (count-2)%9 == 0:
        regex1 = r'\d+\.\d+'
        regex2 = r'neu|xxx|fru|ang|sad|hap|exc|sur|oth|fea|dis'
        match1 = re.search(regex1, line)
        match2 = re.search(regex2, line)
        lst1.append((float(match1[0]), match2[0]))
lst1 = sorted(lst1, key = lambda x: x[0])

result = []
count = 0
for line in trans_file:
    sentence = line[43:]
    sentence = sentence.rstrip()
    result.append((sentence, lst1[count][1]))
    count += 1

df5 = pd.DataFrame(result, columns = ['sentence', 'label'])

# %%
df5
# Out:
#                                              sentence label
# 0                                       n I help you?   neu
# 1                s, please help me.  Where is my bag?   fru
# 2                     need a little more information.   neu
# 3   ere is my bag?  Come on, I've been here for fo...   fru
# 4                 at- What flight did you come in on?   neu
# ..                                                ...   ...
# 65  ll, I don't need to take this kind of abuse ei...   xxx
# 66                                    at's fantastic.   xxx
# 67  en why don't you take your fifty dollars. Get ...   xxx
# 68                                          REATHING]   fru
# 69                                 ank you very much.   ang
#
# [70 rows x 2 columns]

# %%
trans_file = open("IEMOCAP_full_release/Session1/dialog/transcriptions/Ses01M_impro06.txt","r")
emo_file = open("IEMOCAP_full_release/Session1/dialog/EmoEvaluation/Ses01M_impro06.txt","r")
count = -1

lst1 = []
for line in emo_file:
    count += 1
    if count < 2:
        continue
    
    if (count-2)%9 == 0:
        regex1 = r'\d+\.\d+'
        regex2 = r'neu|xxx|fru|ang|sad|hap|exc|sur|oth|fea|dis'
        match1 = re.search(regex1, line)
        match2 = re.search(regex2, line)
        lst1.append((float(match1[0]), match2[0]))
lst1 = sorted(lst1, key = lambda x: x[0])

result = []
count = 0
for line in trans_file:
    sentence = line[43:]
    sentence = sentence.rstrip()
    result.append((sentence, lst1[count][1]))
    count += 1

df6 = pd.DataFrame(result, columns = ['sentence', 'label'])

# %%
df6
# Out:
#                                              sentence label
# 0                                             u okay?   neu
# 1                                 ah, I'm just-- yeah   sad
# 2                     st kind of feel numb, you know.   sad
# 3                                      at's happened?   neu
# 4                                 u didn't even hear?   sad
# 5                                      REATHING] Umm.   sad
# 6          d I've told this story so many times. Umm.   sad
# 7               u don't have to if you don't want to.   neu
# 8   just...I just basically lost someone that was ...   sad
# 9   d I've kind of been dealing with all of the......   sad
# 10                              m sorry to hear that.   sad
# 11   kind of didn't have anyone to take care of th...   sad
# 12                   u've been taking care of it all?   sad
# 13                                             Jesus.   sad
# 14                 's just really...really messed up.   sad
# ...

# %%
trans_file = open("IEMOCAP_full_release/Session1/dialog/transcriptions/Ses01M_impro07.txt","r")
emo_file = open("IEMOCAP_full_release/Session1/dialog/EmoEvaluation/Ses01M_impro07.txt","r")
count = -1

lst1 = []
for line in emo_file:
    count += 1
    if count < 2:
        continue
    
    if (count-2)%9 == 0:
        regex1 = r'\d+\.\d+'
        regex2 = r'neu|xxx|fru|ang|sad|hap|exc|sur|oth|fea|dis'
        match1 = re.search(regex1, line)
        match2 = re.search(regex2, line)
        lst1.append((float(match1[0]), match2[0]))
lst1 = sorted(lst1, key = lambda x: x[0])

result = []
count = 0
for line in trans_file:
    sentence = line[43:]
    sentence = sentence.rstrip()
    result.append((sentence, lst1[count][1]))
    count += 1

df7 = pd.DataFrame(result, columns = ['sentence', 'label'])

# %%
df7
# Out:
#                                              sentence label
# 0   eck this out.  You know how I've told you I've...   exc
# 1                                                 ah.   neu
# 2   ll, this is totally random, I got this full ri...   exc
# 3   AUGHTER]. For softball? That's unbelievable. I...   exc
# 4   r softball.  They're going to pay me to go to ...   exc
# ..                                                ...   ...
# 64                 u're like the rookie? The new kid.   hap
# 65                                                ah.   xxx
# 66  st watch in five years you'll be like on the f...   hap
# 67       m going to have a mustache...On the force...   hap
# 68                                          ll over..   hap
#
# [69 rows x 2 columns]

# %%
df = pd.concat([df1, df2, df3, df4, df5, df6, df7])

# %%
df
# Out:
#                                              sentence label
# 0                                                 xt.   ang
# 1                       s, me. Okay, okay here we go.   fru
# 2                                     window is open.   ang
# 3               ay, so filled out all these forms  --   fru
# 4       is is... Your last- Your first name is Jones?   fru
# ..                                                ...   ...
# 64                 u're like the rookie? The new kid.   hap
# 65                                                ah.   xxx
# 66  st watch in five years you'll be like on the f...   hap
# 67       m going to have a mustache...On the force...   hap
# 68                                          ll over..   hap
#
# [417 rows x 2 columns]

# %%
df.to_csv("session1_3.csv")

# %% [markdown]
# ### part 4

# %%
trans_file = open("IEMOCAP_full_release/Session1/dialog/transcriptions/Ses01M_script01_1.txt","r")
emo_file = open("IEMOCAP_full_release/Session1/dialog/EmoEvaluation/Ses01M_script01_1.txt","r")
count = -1

lst1 = []
for line in emo_file:
    count += 1
    if count < 2:
        continue
    
    if (count-2)%8 == 0:
        regex1 = r'\d+\.\d+'
        regex2 = r'neu|xxx|fru|ang|sad|hap|exc|sur|oth|fea|dis'
        match1 = re.search(regex1, line)
        match2 = re.search(regex2, line)
        lst1.append((float(match1[0]), match2[0]))
lst1 = sorted(lst1, key = lambda x: x[0])

result = []
count = 0
for line in trans_file:
    sentence = line[43:]
    sentence = sentence.rstrip()
    result.append((sentence, lst1[count][1]))
    count += 1

df1 = pd.DataFrame(result, columns = ['sentence', 'label'])

# %%
df1
# Out:
#                                              sentence label
# 0                             What he's going to say?   fru
# 1                                          He saw it.   neu
# 2                                               When?   sur
# 3               He was out here at four this morning.   xxx
# 4    How could he see it?  I was the first one up ...   sur
# ..                                                ...   ...
# 82                   Well, you don't think like that.   ang
# 83                           I am thinking like that.   ang
# 84                      I don't understand you, do I?   ang
# 85            No, you don't.  I'm a pretty tough guy.   sad
# 86                              Well, I can see that.   ang
#
# [87 rows x 2 columns]

# %%
trans_file = open("IEMOCAP_full_release/Session1/dialog/transcriptions/Ses01M_script01_2.txt","r")
emo_file = open("IEMOCAP_full_release/Session1/dialog/EmoEvaluation/Ses01M_script01_2.txt","r")
count = -1

lst1 = []
for line in emo_file:
    count += 1
    if count < 2:
        continue
    
    if (count-2)%7 == 0:
        regex1 = r'\d+\.\d+'
        regex2 = r'neu|xxx|fru|ang|sad|hap|exc|sur|oth|fea|dis'
        match1 = re.search(regex1, line)
        match2 = re.search(regex2, line)
        lst1.append((float(match1[0]), match2[0]))
lst1 = sorted(lst1, key = lambda x: x[0])

result = []
count = 0
for line in trans_file:
    sentence = line[43:]
    sentence = sentence.rstrip()
    result.append((sentence, lst1[count][1]))
    count += 1

df2 = pd.DataFrame(result, columns = ['sentence', 'label'])

# %%
df2
# Out:
#                                              sentence label
# 0                         Why did he invite her here?   ang
# 1                      Well, maybe he wanted see her.   neu
# 2    It's been three and a half years.  Why all of...   ang
# 3    Well uh, He grew up next door to the girl, wh...   neu
# 4    Don't look at me like that.  He didn't tell m...   fru
# 5                        He's not going to marry her.   xxx
# 6        How do you know he's even thinking about it?   fru
# 7                             it's got that about it.   xxx
# 8                                         Oh so what?   fru
# 9                         What is going on here, Joe?   ang
# 10                          Okay, now listen, kids...   fru
# 11   The girl is not Larry's.  If the girl is Larr...   ang
# 12             Listen. Line. You can't read her mind.   fru
# 13   Then why is she still single?  New York is fu...   xxx
# 14              And how do you know why she's waited.   neu
# ...

# %%
trans_file = open("IEMOCAP_full_release/Session1/dialog/transcriptions/Ses01M_script01_3.txt","r")
emo_file = open("IEMOCAP_full_release/Session1/dialog/EmoEvaluation/Ses01M_script01_3.txt","r")
count = -1

lst1 = []
for line in emo_file:
    count += 1
    if count < 2:
        continue
    
    if (count-2)%7 == 0:
        regex1 = r'\d+\.\d+'
        regex2 = r'neu|xxx|fru|ang|sad|hap|exc|sur|oth|fea|dis'
        match1 = re.search(regex1, line)
        match2 = re.search(regex2, line)
        lst1.append((float(match1[0]), match2[0]))
lst1 = sorted(lst1, key = lambda x: x[0])

result = []
count = 0
for line in trans_file:
    sentence = line[43:]
    sentence = sentence.rstrip()
    result.append((sentence, lst1[count][1]))
    count += 1

df3 = pd.DataFrame(result, columns = ['sentence', 'label'])

# %%
df3
# Out:
#                                              sentence label
# 0         The only one I know still love his parents.   neu
# 1     Yeah, that kind of went out of style didn't it?   hap
# 2              Oh it's not bad thing it's good thing.   neu
# 3          You know it's nice here, the air is sweet.   xxx
# 4                          You're not sorry you came?   hap
# ..                                                ...   ...
# 70   Everything Chris do you understand that?  To ...   xxx
# 71   And your money there's nothing wrong in your ...   xxx
# 72                                           Annie...   xxx
# 73               I'm going to make a fortune for you.   hap
# 74                    What would I do with a fortune?   hap
#
# [75 rows x 2 columns]

# %%
trans_file = open("IEMOCAP_full_release/Session1/dialog/transcriptions/Ses01M_script02_1.txt","r")
emo_file = open("IEMOCAP_full_release/Session1/dialog/EmoEvaluation/Ses01M_script02_1.txt","r")
count = -1

lst1 = []
for line in emo_file:
    count += 1
    if count < 2:
        continue
    
    if (count-2)%7 == 0:
        regex1 = r'\d+\.\d+'
        regex2 = r'neu|xxx|fru|ang|sad|hap|exc|sur|oth|fea|dis'
        match1 = re.search(regex1, line)
        match2 = re.search(regex2, line)
        lst1.append((float(match1[0]), match2[0]))
lst1 = sorted(lst1, key = lambda x: x[0])

result = []
count = 0
for line in trans_file:
    sentence = line[43:]
    sentence = sentence.rstrip()
    result.append((sentence, lst1[count][1]))
    count += 1

df4 = pd.DataFrame(result, columns = ['sentence', 'label'])

# %%
df4
# Out:
#                                              sentence label
# 0    What time is it?  God, this is great, isn't i...   exc
# 1    Of course I did want to a little further up t...   exc
# 2                                           I'm fine.   xxx
# 3      Look, there what's that, what's that?  Is it--   exc
# 4                       No, I think that's just foam.   xxx
# ..                                                ...   ...
# 67   Like some little time release fire cracker we...   exc
# 68   And form the line and started swimming, swimm...   exc
# 69   It's like urgency that's pure urge you know. ...   exc
# 70   It's crazy.  Look at this, I'm giving myself ...   exc
# 71                                   That's the wind.   xxx
#
# [72 rows x 2 columns]

# %%
trans_file = open("IEMOCAP_full_release/Session1/dialog/transcriptions/Ses01M_script02_2.txt","r")
emo_file = open("IEMOCAP_full_release/Session1/dialog/EmoEvaluation/Ses01M_script02_2.txt","r")
count = -1

lst1 = []
for line in emo_file:
    count += 1
    if count < 2:
        continue
    
    if (count-2)%7 == 0:
        regex1 = r'\d+\.\d+'
        regex2 = r'neu|xxx|fru|ang|sad|hap|exc|sur|oth|fea|dis'
        match1 = re.search(regex1, line)
        match2 = re.search(regex2, line)
        lst1.append((float(match1[0]), match2[0]))
lst1 = sorted(lst1, key = lambda x: x[0])

result = []
count = 0
for line in trans_file:
    sentence = line[43:]
    sentence = sentence.rstrip()
    result.append((sentence, lst1[count][1]))
    count += 1

df5 = pd.DataFrame(result, columns = ['sentence', 'label'])

# %%
df5
# Out:
#                                               sentence label
# 0              They're out there swimming right now...   xxx
# 1     ...to this spot for this massive celebration ...   exc
# 2     Look at this, my hairs are standing up my arm...   exc
# 3                                     That's the wind.   neu
# 4                        Well, so?  What do you think?   exc
# ..                                                 ...   ...
# 98                                   Augie, I'm sorry.   sad
# 99                                              Shh...   hap
# 100       If we are really quiet, the fish might come.   hap
# 101                                            Or not.   neu
# 102                                            Or not.   neu
#
# [103 rows x 2 columns]

# %%
trans_file = open("IEMOCAP_full_release/Session1/dialog/transcriptions/Ses01M_script03_1.txt","r")
emo_file = open("IEMOCAP_full_release/Session1/dialog/EmoEvaluation/Ses01M_script03_1.txt","r")
count = -1

lst1 = []
for line in emo_file:
    count += 1
    if count < 2:
        continue
    
    if (count-2)%7 == 0:
        regex1 = r'\d+\.\d+'
        regex2 = r'neu|xxx|fru|ang|sad|hap|exc|sur|oth|fea|dis'
        match1 = re.search(regex1, line)
        match2 = re.search(regex2, line)
        lst1.append((float(match1[0]), match2[0]))
lst1 = sorted(lst1, key = lambda x: x[0])

result = []
count = 0
for line in trans_file:
    sentence = line[43:]
    sentence = sentence.rstrip()
    result.append((sentence, lst1[count][1]))
    count += 1

df6 = pd.DataFrame(result, columns = ['sentence', 'label'])

# %%
df6
# Out:
#                                              sentence label
# 0                                           Good God.   fea
# 1                             Do you think it's them?   xxx
# 2                                           I wonder.   fea
# 3    Freda is the only one who knows we are here. ...   fea
# 4                                  Must be them then.   xxx
# ..                                                ...   ...
# 80                                    oh...[LAUGHTER]   hap
# 81                    We were very much younger then.   hap
# 82                                 Very much sillier.   hap
# 83   However, I do believe the real cause of that ...   xxx
# 84             Oh you knew there was nothing in that.   exc
#
# [85 rows x 2 columns]

# %%
trans_file = open("IEMOCAP_full_release/Session1/dialog/transcriptions/Ses01M_script03_2.txt","r")
emo_file = open("IEMOCAP_full_release/Session1/dialog/EmoEvaluation/Ses01M_script03_2.txt","r")
count = -1

lst1 = []
for line in emo_file:
    count += 1
    if count < 2:
        continue
    
    if (count-2)%7 == 0:
        regex1 = r'\d+\.\d+'
        regex2 = r'neu|xxx|fru|ang|sad|hap|exc|sur|oth|fea|dis'
        match1 = re.search(regex1, line)
        match2 = re.search(regex2, line)
        lst1.append((float(match1[0]), match2[0]))
lst1 = sorted(lst1, key = lambda x: x[0])

result = []
count = 0
for line in trans_file:
    sentence = line[43:]
    sentence = sentence.rstrip()
    result.append((sentence, lst1[count][1]))
    count += 1

df7 = pd.DataFrame(result, columns = ['sentence', 'label'])

# %%
df7
# Out:
#                                              sentence label
# 0                                          [LAUGHTER]   xxx
# 1             [LAUGHTER] Utterly, utterly ridiculous.   xxx
# 2                     We were very much younger then.   xxx
# 3                                  Very much sillier.   xxx
# 4                                              Mmhmm.   xxx
# ..                                                ...   ...
# 81   This is the end do you hear me?  Finally and ...   ang
# 82                        You're not going like this.   ang
# 83   Oh yes I am...Oh yes I am. Let go of me. You ...   ang
# 84                                     No you're not.   ang
# 85   Shut up. Shut up. I wouldn't marry you again ...   ang
#
# [86 rows x 2 columns]

# %%
df = pd.concat([df1, df2, df3, df4, df5, df6, df7])

# %%
df
# Out:
#                                              sentence label
# 0                             What he's going to say?   fru
# 1                                          He saw it.   neu
# 2                                               When?   sur
# 3               He was out here at four this morning.   xxx
# 4    How could he see it?  I was the first one up ...   sur
# ..                                                ...   ...
# 81   This is the end do you hear me?  Finally and ...   ang
# 82                        You're not going like this.   ang
# 83   Oh yes I am...Oh yes I am. Let go of me. You ...   ang
# 84                                     No you're not.   ang
# 85   Shut up. Shut up. I wouldn't marry you again ...   ang
#
# [541 rows x 2 columns]

# %%
df.to_csv("session1_4.csv")

# %% [markdown]
# ### combination

# %%
file1 = pd.read_csv("session1_1.csv", index_col=0)
file2 = pd.read_csv("session1_2.csv", index_col=0)
file3 = pd.read_csv("session1_3.csv", index_col=0)
file4 = pd.read_csv("session1_4.csv", index_col=0)

# %%
df = pd.concat([file1, file2, file3, file4])

# %%
df
# Out:
#                                              sentence label
# 0                                          Excuse me.   neu
# 1                             Do you have your forms?   fru
# 2                                               Yeah.   neu
# 3                                    Let me see them.   fru
# 4                                 Is there a problem?   neu
# ..                                                ...   ...
# 81   This is the end do you hear me?  Finally and ...   ang
# 82                        You're not going like this.   ang
# 83   Oh yes I am...Oh yes I am. Let go of me. You ...   ang
# 84                                     No you're not.   ang
# 85   Shut up. Shut up. I wouldn't marry you again ...   ang
#
# [1819 rows x 2 columns]

# %%
df.to_csv("session1.csv")
